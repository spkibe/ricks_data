# %%
import pandas as pd

# %%
phosphate = pd.read_excel('RICKY EXCEL.xlsx', sheet_name=1)

# %%
phosphate
# Out:
#   STATION   JUNE   JULY  AUGUST
# 0       A  0.097  0.032   0.012
# 1       B  0.830  0.760   0.670
# 2       C  1.930  1.390   1.260
# 3       D  1.060  0.980   0.890

# %%
phosphate = phosphate.set_index('STATION')

# %%
phosphate = phosphate.stack()

# %%
phosphate = phosphate.to_frame()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-51-2a656bc0aea1> in <module>
# ----> 1 phosphate = phosphate.to_frame(name="levels")
#
# ~/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'to_frame'

# %%
phosphate.columns
# Out:
# RangeIndex(start=0, stop=1, step=1)

# %%
phosphate
# Out:
#                     0
# STATION
# A       JUNE    0.097
#         JULY    0.032
#         AUGUST  0.012
# B       JUNE    0.830
#         JULY    0.760
#         AUGUST  0.670
# C       JUNE    1.930
#         JULY    1.390
#         AUGUST  1.260
# D       JUNE    1.060
#         JULY    0.980
#         AUGUST  0.890

# %%
#df.rename(columns={"A": "a", "B": "c"})

# %%
phosphate = phosphate.reset_index()

# %%
phosphate
# Out:
#    STATION   month  levels
# 0        A    JUNE   0.097
# 1        A    JULY   0.032
# 2        A  AUGUST   0.012
# 3        B    JUNE   0.830
# 4        B    JULY   0.760
# 5        B  AUGUST   0.670
# 6        C    JUNE   1.930
# 7        C    JULY   1.390
# 8        C  AUGUST   1.260
# 9        D    JUNE   1.060
# 10       D    JULY   0.980
# 11       D  AUGUST   0.890

# %%
phosphate = phosphate.rename(columns={'level_1' : 'month', 0: 'levels'})

# %%
phosphate.reset_index()
# Out:
#    STATION level_1  levels
# 0        A    JUNE   0.097
# 1        A    JULY   0.032
# 2        A  AUGUST   0.012
# 3        B    JUNE   0.830
# 4        B    JULY   0.760
# 5        B  AUGUST   0.670
# 6        C    JUNE   1.930
# 7        C    JULY   1.390
# 8        C  AUGUST   1.260
# 9        D    JUNE   1.060
# 10       D    JULY   0.980
# 11       D  AUGUST   0.890

# %%
phosphate
# Out:
#                 levels
# STATION
# A       JUNE     0.097
#         JULY     0.032
#         AUGUST   0.012
# B       JUNE     0.830
#         JULY     0.760
#         AUGUST   0.670
# C       JUNE     1.930
#         JULY     1.390
#         AUGUST   1.260
# D       JUNE     1.060
#         JULY     0.980
#         AUGUST   0.890

# %%
phosphate.to_csv('phosphate_ricks.csv')

# %%
phosphate
# Out:
# 0  STATION        A
#    JUNE       0.097
#    JULY       0.032
#    AUGUST     0.012
# 1  STATION        B
#    JUNE        0.83
#    JULY        0.76
#    AUGUST      0.67
# 2  STATION        C
#    JUNE        1.93
#    JULY        1.39
#    AUGUST      1.26
# 3  STATION        D
#    JUNE        1.06
#    JULY        0.98
#    AUGUST      0.89
# dtype: object

# %%
df = pd.read_csv('phosphate_rick.csv')

# %%
df
# Out:
#    STATION Unnamed: 1  levels
# 0        A       JUNE   0.097
# 1        A       JULY   0.032
# 2        A     AUGUST   0.012
# 3        B       JUNE   0.830
# 4        B       JULY   0.760
# 5        B     AUGUST   0.670
# 6        C       JUNE   1.930
# 7        C       JULY   1.390
# 8        C     AUGUST   1.260
# 9        D       JUNE   1.060
# 10       D       JULY   0.980
# 11       D     AUGUST   0.890

# %%
nitrates = pd.read_excel('RICKY EXCEL.xlsx', sheet_name='Sheet2')

# %%
nitrates
# Out:
#   STATION   JUNE   JULY  AUGUST
# 0       A  0.097  0.032   0.012
# 1       B  0.830  0.760   0.670
# 2       C  1.930  1.390   1.260
# 3       D  1.060  0.980   0.890

# %%
nitrates = nitrates.set_index('STATION')

# %%
nitrates = nitrates.stack()
nitrates
# Out:
# STATION
# A        JUNE      0.097
#          JULY      0.032
#          AUGUST    0.012
# B        JUNE      0.830
#          JULY      0.760
#          AUGUST    0.670
# C        JUNE      1.930
#          JULY      1.390
#          AUGUST    1.260
# D        JUNE      1.060
#          JULY      0.980
#          AUGUST    0.890
# dtype: float64

# %%
nitrates = nitrates.to_frame()

# %%
nitrates
# Out:
#                     0
# STATION
# A       JUNE    0.097
#         JULY    0.032
#         AUGUST  0.012
# B       JUNE    0.830
#         JULY    0.760
#         AUGUST  0.670
# C       JUNE    1.930
#         JULY    1.390
#         AUGUST  1.260
# D       JUNE    1.060
#         JULY    0.980
#         AUGUST  0.890

# %%
nitrates = nitrates.reset_index()

# %%
nitrates
# Out:
#    STATION level_1      0
# 0        A    JUNE  0.097
# 1        A    JULY  0.032
# 2        A  AUGUST  0.012
# 3        B    JUNE  0.830
# 4        B    JULY  0.760
# 5        B  AUGUST  0.670
# 6        C    JUNE  1.930
# 7        C    JULY  1.390
# 8        C  AUGUST  1.260
# 9        D    JUNE  1.060
# 10       D    JULY  0.980
# 11       D  AUGUST  0.890

# %%
nitrates.columns
# Out:
# Index(['STATION', 'level_1', 0], dtype='object')

# %%
nitrates = nitrates.rename(columns={'level_1' : 'month', 0: 'levels'})
nitrates
# Out:
#    STATION   month  levels
# 0        A    JUNE   0.097
# 1        A    JULY   0.032
# 2        A  AUGUST   0.012
# 3        B    JUNE   0.830
# 4        B    JULY   0.760
# 5        B  AUGUST   0.670
# 6        C    JUNE   1.930
# 7        C    JULY   1.390
# 8        C  AUGUST   1.260
# 9        D    JUNE   1.060
# 10       D    JULY   0.980
# 11       D  AUGUST   0.890

# %%
nitrates.to_csv('nitrates.csv')
